# %%
# !pip install transformers==4.33.2
# Out:
# Collecting transformers==4.33.2
#   Downloading transformers-4.33.2-py3-none-any.whl.metadata (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.2) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.2) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.2) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.33.2) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.2) (2023.11.17)
# Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 28.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.33.0
#     Uninstalling transformers-4.33.0:
#       Successfully uninstalled transformers-4.33.0
# Successfully installed transformers-4.33.2

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("/kaggle/input/chatglm2/pytorch/6b/1", trust_remote_code=True)
model = AutoModel.from_pretrained("/kaggle/input/chatglm2/pytorch/6b/1", trust_remote_code=True).half().cuda()
model = model.eval()
# Out:
# 2024-02-15 18:40:42.826969: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-15 18:40:42.827083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-15 18:40:43.004799: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
response, history = model.chat(tokenizer, "胃痛是什么原因引起的？", history=[])
print(response)
# Out:
# 胃痛的原因很多,以下是一些常见的原因:
#
# 1. 胃炎:胃炎是指胃黏膜受损或发炎。胃炎的原因包括幽门螺杆菌感染、非甾体抗炎药(如阿司匹林和NSAIDs)、胆汁反流、胆石症、胃酸分泌过多等。
#
# 2. 胃溃疡:胃溃疡是胃黏膜上的损伤和溃疡形成。胃溃疡的原因包括胃炎、幽门螺杆菌感染、胃酸分泌过多、十二指肠球溃疡等。
#
# 3. 胃酸倒流:胃酸倒流是指胃内的胃酸或其他消化液倒流到食道中,引起烧心、嗓子灼痛等症状。胃酸倒流的原因包括肥胖、吸烟、饮酒、饮食习惯等。
#
# 4. 胃炎:胃炎是指胃黏膜受损或发炎。胃炎的原因包括幽门螺杆菌感染、非甾体抗炎药(如阿司匹林和NSAIDs)、胆汁反流、胆石症、胃酸分泌过多等。
#
# 5. 胃痛和胃炎有关,因为胃炎可以导致胃黏膜受损,从而引起胃痛。胃炎的原因包括幽门螺杆菌感染、非甾体抗炎药(如阿司匹林和NSAIDs)、胆汁反流、胆石症、胃酸分泌过多等。
#
# 如果经常感到胃痛,建议尽早咨询医生,以确定确切的原因并制定适当的治疗计划。

# %%
response, history = model.chat(tokenizer, "What causes stomach pain?", history=[])
print(response)
# Out:
# Stomach pain can have a variety of causes, ranging from mild discomfort to severe discomfort or abdominal pain. Some common causes of stomach pain include:
#
# 1. Digestive disorders: These disorders can cause stomach pain, such as indigestion, constipation, or heartburn.
# 2. Inflammatory bowel disease: Conditions such as Crohn's disease or ulcerative colitis can cause abdominal pain and stomach inflammation.
# 3. Small intestine bacterial overgrowth (SIBO): This condition can cause abdominal pain and bloating.
# 4. Gastroesophageal reflux disease (GERD): This condition can cause stomach pain and discomfort, especially at night.
# 5. Peptic ulcer disease: This condition can cause severe, constant abdominal pain.
# 6. Gastrointestinal infections: This can cause stomach pain, fever, and nausea.
# 7. Certain medications: Certain medications, such as nonsteroidal anti-inflammatory drugs (NSAIDs) or certain types of cancer medications, can cause stomach pain.
#
# If you are experiencing stomach pain, it is important to speak with a healthcare provider to determine the cause and receive appropriate treatment.

# %%
response, history = model.chat(tokenizer, "What is Football ?", history=[])
print(response)
# Out:
# Football, also known as soccer, is a popular team sport that is played by two teams of ten players each on a large playing field. The objective of the game is to score goals by kicking or headers the ball past the opponent's goalpost.
#
# The game began in the United Kingdom and spread to other countries throughout the world. It is played at the international level by national teams and at a competitive level by clubs. It is one of the most popular sports in the world and has a large following, with billions of people tuning in to watch major tournaments and matches.
